# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhilash-Bee/MachineLearning_DeepLearning_Projects/blob/main/Regression/Student_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Will be updated shortly...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Machine Learning Projects/2. RegressionProjects/2. StudentPerformance/study_performance.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# !pip install ydata_profiling

# %%
# !pip install --upgrade matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 22.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.26.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.1 which is incompatible.
# ...

# %%
from ydata_profiling import ProfileReport
import matplotlib

profile = ProfileReport(df, dark_mode=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-03-27 07:05:36.912106&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# @import url(&quot;https://fonts.googleapis.com/css?family=Lato:400,700,400italic&quot;);/*!
#  * bootswatch v3.3.7
#  * Homepage: http://bootswatch.com
#  * Copyright 2012-2016 Thomas Park
#  * Licensed under MIT
#  * Based on Bootstrap
# *//*!
# ...

# %%
import missingno

missingno.heatmap(df, figsize=(10, 7));
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %%
# !pip install pivottablejs

# %%
from pivottablejs import pivot_ui

pivot_ui(df)

# %%
from IPython.display import HTML

HTML('/content/pivottablejs.html')
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>PivotTable.js</title>
#
#         <!-- external libs from cdnjs -->
#         <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.css">
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-csv/0.71/jquery.csv-0.71.min.js"></script>
#
#
# ...

# %%
HTML('/content/pivottablejs.html')
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>PivotTable.js</title>
#
#         <!-- external libs from cdnjs -->
#         <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.css">
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-csv/0.71/jquery.csv-0.71.min.js"></script>
#
#
# ...

# %%
# !pip install mitosheet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 44.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 50.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 8.1 MB/s eta 0:00:00
# ...

# %%
import mitosheet

mitosheet.sheet(analysis_to_replay="id-ymyxvhaoes")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-a8c998fd01c4> in <cell line: 3>()
#       1 import mitosheet
#       2
# ----> 3 mitosheet.sheet(analysis_to_replay="id-ymyxvhaoes")
#
# /usr/local/lib/python3.10/dist-packages/mitosheet/mito_backend.py in sheet(analysis_to_replay, view_df, sheet_functions, importers, editors, *args)
#     416     if is_in_vs_code() or is_in_google_colab():
#     417         log('mitosheet_sheet_call_location_failed', failed=True)
# --> 418         raise Exception("The mitosheet currently only works in JupyterLab.\n\nTo see instructions on getting Mitosheet running in JupyterLab, find install instructions here: https://docs.trymito.io/getting-started/installing-mito")
#     419     elif is_dash():
#     420         log('mitosheet_sheet_call_location_failed', failed=True)
#
# ...

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.columns[:-3]
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course'],
#       dtype='object')

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
fig, ax = plt.subplots(1, 5, figsize=(22, 5))

for i, col in enumerate(list(df.columns[:-3])):
    sns.countplot(x=df[col], ax=ax[i], palette=sns.palettes.mpl_palette('Dark2'))
    for container in ax[i].containers:
        ax[i].bar_label(container)

ax[2].set_xticklabels(df['parental_level_of_education'].unique(), rotation=45, ha='right');

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

for i, col in enumerate(list(df.columns[-3:])):
    sns.histplot(x=df[col], ax=ax[i], kde=True)

# %%
fig = plt.figure(figsize=(22, 5))

plt.subplot(161)
ax = df[df['math_score'] >= 80].groupby('gender')['math_score'].count().plot(kind='bar', rot='horizontal', color=['r', 'g'])
ax.bar_label(ax.containers[0])
ax.set_title('Math score >= 80')

plt.subplot(162)
ax = df[df['math_score'] < 35].groupby('gender')['math_score'].count().plot(kind='bar', rot='horizontal', color=['r', 'g'])
ax.bar_label(ax.containers[0])
ax.set_title('Math score < 35')

plt.subplot(163)
ax = df[df['reading_score'] >= 80].groupby('gender')['math_score'].count().plot(kind='bar', rot='horizontal', color=['r', 'g'])
ax.bar_label(ax.containers[0])
ax.set_title('Reading score >= 80')

plt.subplot(164)
ax = df[df['reading_score'] < 35].groupby('gender')['math_score'].count().plot(kind='bar', rot='horizontal', color=['r', 'g'])
ax.bar_label(ax.containers[0])
ax.set_title('Reading score < 35')

plt.subplot(165)
ax = df[df['writing_score'] >= 80].groupby('gender')['math_score'].count().plot(kind='bar', rot='horizontal', color=['r', 'g'])
ax.bar_label(ax.containers[0])
ax.set_title('writing score >= 80')

plt.subplot(166)
ax = df[df['writing_score'] < 35].groupby('gender')['math_score'].count().plot(kind='bar', rot='horizontal', color=['r', 'g'])
ax.bar_label(ax.containers[0])
ax.set_title('writing score < 35');

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
fig = plt.figure(figsize=(10, 7))
sns.scatterplot(df, x='writing_score', y='reading_score', hue='math_score');

# %% [markdown]
# **ANALYSIS:** The data is linear.

# %% [markdown]
# ## Splitting the data

# %%
X = pd.concat([df[df.columns[:5]], df[df.columns[-2:]]], axis=1)
y = df[['math_score']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((800, 7), (800, 1), (200, 7), (200, 1))

# %% [markdown]
# ## Categories of all categorical data

# %%
for col in df.columns[:5]:
    print(f'{col}: {df[col].unique()}')
# Out:
# gender: ['female' 'male']
# race_ethnicity: ['group B' 'group C' 'group A' 'group D' 'group E']
# parental_level_of_education: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# lunch: ['standard' 'free/reduced']
# test_preparation_course: ['none' 'completed']

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

for col in df.columns[:5]:
    encoder = LabelEncoder()
    encoder.fit(X_train[col])
    X_train[col] = encoder.transform(X_train[col])
    X_test[col] = encoder.transform(X_test[col])

# %%
X_train.head()
# Out:
#      gender  race_ethnicity  ...  reading_score  writing_score
# 578       0               1  ...             56             58
# 66        1               3  ...             37             37
# 39        1               1  ...             56             57
# 302       0               2  ...             84             81
# 974       0               0  ...             63             67
#
# [5 rows x 7 columns]

# %%
sns.pairplot(pd.concat([X_train, y_train], axis=1), diag_kind='kde');

# %% [markdown]
# ## Training the model

# %%
# !pip install Cython==0.29.36
# !pip uninstall scipy -y
# !pip install scipy==1.9
# !pip uninstall pyparsing -y
# !pip install pyparsing==2.4
# !pip uninstall scikit_learn -y
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# Found existing installation: scipy 1.9.0
# Uninstalling scipy-1.9.0:
#   Successfully uninstalled scipy-1.9.0
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# ...
#   Using cached scipy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.14 requires scikit-learn, which is not installed.
# librosa 0.10.1 requires scikit-learn>=0.20.0, which is not installed.
# sklearn-pandas 2.2.0 requires scikit-learn>=0.23.0, which is not installed.
# ...

# %%
# !pip uninstall imbalanced-learn -y
# !pip uninstall mlxtend -y
# !pip uninstall yellowbrick -y
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# WARNING: Skipping imbalanced-learn as it is not installed.
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# WARNING: Skipping mlxtend as it is not installed.
# Found existing installation: yellowbrick 1.5
# Uninstalling yellowbrick-1.5:
#   Successfully uninstalled yellowbrick-1.5

# %%
# !pip install scikit-learn==0.24.2 --no-build-isolation
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# ...
#   Using cached scikit-learn-0.24.2.tar.gz (7.5 MB)
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-learn: filename=scikit_learn-0.24.2-cp310-cp310-linux_x86_64.whl size=22237953 sha256=69363d8533675ace4250661864627a6d85309596d84d90a27ba959d7f77d3e06
#   Stored in directory: /root/.cache/pip/wheels/13/a4/68/4e78865652fa14db4a162b491e5138565f97646f9e1f2ab8cc
# Successfully built scikit-learn
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.0.0 requires scikit-learn>=1.2.2, but you have scikit-learn 0.24.2 which is incompatible.
# ...

# %%
# !pip install auto-sklearn
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (/usr/local/lib/python3.10/dist-packages)
# ...
#   Using cached auto-sklearn-0.15.0.tar.gz (6.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 12.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 24.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 5.2 MB/s eta 0:00:00
# ...
#   Created wheel for auto-sklearn: filename=auto_sklearn-0.15.0-py3-none-any.whl size=6641936 sha256=78fc62976470622af97f79f072602556c03b43071111c1c48843141e4085b176
# ...

# %%
from autosklearn.regression import AutoSklearnRegressor

# %%
automl = AutoSklearnRegressor(300)

automl.fit(X_train, y_train)
# Out:
# AutoSklearnRegressor(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                      per_run_time_limit=30, time_left_for_this_task=300)

# %%
automl.leaderboard(detailed=True)
# Out:
#           rank  ensemble_weight  ... balancing_strategy   config_origin
# model_id                         ...
# 6            1             0.44  ...               None  Initial design
# 17           2             0.02  ...               None  Initial design
# 10           3             0.38  ...               None  Initial design
# 11           4             0.16  ...               None  Initial design
#
# [4 rows x 16 columns]

# %%
automl.score(X_test, y_test)
# Out:
# 0.8199611886885136

# %%
y_pred = automl.predict(X_test)

y_pred[:10]
# Out:
# array([61.44140697, 46.89338601, 53.39818716, 28.32104158, 77.58781981,
#        63.0177989 , 99.37674022, 71.04466879, 67.7837708 , 50.92369401])

# %%
y_true = np.squeeze(y_test.values)

# %%
fig = plt.figure(figsize=(18, 6))
plt.plot(y_true, 'o')
plt.plot(y_pred, 'r');

# %% [markdown]
# ## Scoring

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
mean_absolute_error(y_true, y_pred)
# Out:
# 4.830916234254837

# %%
mean_squared_error(y_true, y_pred)
# Out:
# 35.199203459727116

# %%
mean_absolute_percentage_error(y_true, y_pred)
# Out:
# 0.0785830931230867

# %% [markdown]
# ---
# ---
